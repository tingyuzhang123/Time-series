# %%
import importlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt                  # plots

# %%
df = pd.read_csv('daily-total-female-births.csv')

# %%
df.head()
# Out:
#          Date  Births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
print(df.shape)
# Out:
# (365, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 2 columns):
# Date      365 non-null object
# Births    365 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 5.8+ KB

# %%
df.columns = ['Date','Births']
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date') 
print(df.head(2))
print(df.tail(2))
print(df.shape)
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
#             Births
# Date
# 1959-12-30      55
# 1959-12-31      50
# (365, 1)

# %%
print(df['1959-06':'1959-07'])
# Out:
#             Births
# Date
# 1959-06-01      45
# 1959-06-02      46
# 1959-06-03      34
# 1959-06-04      35
# 1959-06-05      48
# 1959-06-06      51
# 1959-06-07      36
# 1959-06-08      33
# 1959-06-09      46
# 1959-06-10      42
# 1959-06-11      48
# 1959-06-12      34
# 1959-06-13      41
# 1959-06-14      35
# 1959-06-15      40
# 1959-06-16      34
# 1959-06-17      30
# 1959-06-18      36
# 1959-06-19      40
# 1959-06-20      39
# 1959-06-21      45
# 1959-06-22      38
# 1959-06-23      47
# 1959-06-24      33
# 1959-06-25      30
# 1959-06-26      42
# 1959-06-27      43
# 1959-06-28      41
# 1959-06-29      41
# 1959-06-30      59
# ...            ...
# 1959-07-02      45
# 1959-07-03      38
# 1959-07-04      37
# 1959-07-05      45
# 1959-07-06      42
# 1959-07-07      57
# 1959-07-08      46
# 1959-07-09      51
# 1959-07-10      41
# 1959-07-11      47
# 1959-07-12      26
# 1959-07-13      35
# 1959-07-14      44
# 1959-07-15      41
# 1959-07-16      42
# ...

# %%
print(df.truncate(before = '1959-11-25'))
df[(df['Births']<50) & (df['Births']>40)]
# Out:
#             Births
# Date
# 1959-11-25      45
# 1959-11-26      49
# 1959-11-27      51
# 1959-11-28      46
# 1959-11-29      44
# 1959-11-30      52
# 1959-12-01      45
# 1959-12-02      32
# 1959-12-03      46
# 1959-12-04      41
# 1959-12-05      34
# 1959-12-06      33
# 1959-12-07      36
# 1959-12-08      49
# 1959-12-09      43
# 1959-12-10      43
# 1959-12-11      34
# 1959-12-12      39
# 1959-12-13      35
# 1959-12-14      52
# 1959-12-15      47
# 1959-12-16      52
# 1959-12-17      39
# 1959-12-18      40
# 1959-12-19      42
# 1959-12-20      42
# 1959-12-21      53
# 1959-12-22      39
# 1959-12-23      40
# 1959-12-24      38
# 1959-12-25      44
# 1959-12-26      34
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#             Births
# Date
# 1959-01-05      44
# 1959-01-07      45
# 1959-01-08      43
# 1959-01-14      47
# 1959-01-15      45
# 1959-01-18      43
# 1959-01-19      41
# ...

# %%
BirthNumber.plot( y=["Births"])
plt.title('Brith Rate(according to year)')
plt.grid(True)
plt.show()

# %%
print(df.resample('M').sum())
print(df.resample('Q').sum().head())
# Out:
#             Births
# Date
# 1959-01-31    1213
# 1959-02-28    1148
# 1959-03-31    1218
# 1959-04-30    1195
# 1959-05-31    1208
# 1959-06-30    1212
# 1959-07-31    1300
# 1959-08-31    1351
# 1959-09-30    1446
# 1959-10-31    1368
# 1959-11-30    1350
# 1959-12-31    1314
#             Births
# Date
# 1959-03-31    3579
# 1959-06-30    3615
# 1959-09-30    4097
# 1959-12-31    4032

# %%
df.resample('M').sum().plot(grid = True)
plt.title('Birth rate (monthly data)')
# Out:
# Text(0.5,1,'Birth rate (monthly data)')

# %%
dm = df['Births'].resample('M').sum()

# %%
dm.max()
# Out:
# 1446

# %%
dm.min()
# Out:
# 1148

# %%
dm.mean()
# Out:
# 1276.9166666666667

# %%
pd.plotting.autocorrelation_plot(df['Births'].resample("M").median())

# %%
pd.plotting.autocorrelation_plot(df['Births'].resample("M").mean())

# %%
pd.plotting.autocorrelation_plot(df['Births'].resample("M").max())

# %%
pd.plotting.autocorrelation_plot(df['Births'].resample("M").min())

# %%
df[['Births']].resample("M").median().diff().plot(subplots=True, figsize=(15,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1c2317f898>],
#       dtype=object)

# %%
df[["Births"]].resample("M").median().plot(subplots=True, figsize=(15,4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1c23296b70>],
#       dtype=object)

# %%
df[["Births"]].rolling(6*12).median().plot(figsize=(15,4))
